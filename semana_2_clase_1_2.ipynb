# %% [markdown]
# # **Clase 1 - Semana 2**

# %% [markdown]
# *Tópicos Selectos Proceso Químicos: Análisis de Datos con Python*

# %% [markdown]
# # **Ejemplos de tipos de datos en python**

# %%
edades = [10, 25.5, True, "treinta"]
print(edades)
# Out:
# [10, 25.5, True, 'treinta']

# %% [markdown]
# # Listas

# %%
lista1 = [2,4,6,8,10]
lista2 = [25.5,26.9,30.2]
lista3 = ["treinta", "cuarenta", "cincuenta"]
lista4 = [True, False, False, True] #Una lista es una secuencia de valores.

# %%
lista1 #para llamar listas solo marcalas con numeros distintos
# Out:
# [2, 4, 6, 8, 10]

# %%
lista3
# Out:
# ['treinta', 'cuarenta', 'cincuenta']

# %% [markdown]
# **para cambiar el valor de una lista:**

# %%
lista1 [0] = 7 #el valor que venga en los corchetes se cambiara por el que se indique despues del igual

# %%
lista1
# Out:
# [7, 4, 6, 8, 10]

# %% [markdown]
# **para llamar datos:**

# %%
lista3 [2]
# Out:
# 'cincuenta'

# %% [markdown]
# **para añadir datos usamos append**

# %%
lista1 #append sirve para añadir datos
# Out:
# [7, 4, 6, 8, 10]

# %%
lista1.append (14)

# %%
lista1
# Out:
# [7, 4, 6, 8, 10, 14]

# %% [markdown]
# **remove sirve para eliminar datos**

# %%
lista1.remove (4) #para eliminar texto usamos remove

# %%
lista1
# Out:
# [7, 6, 8, 10, 14]

# %% [markdown]
# # Cadenas de Texto

# %%
a= "soy alumne de la uam" #las cadenas de texto no se pueden modificar

# %%
a[8]
# Out:
# 'n'

# %%
b= a.replace ("uam", "uami") #si necesitamos modificar una cadena de texto, tenemos que utilizar la función que cree una nueva cadena, como la función .replace()
b
# Out:
# 'soy alumne de la uami'

# %% [markdown]
# **para convertir de numero a texto**

# %%
g= 7.8 #muchos objetos de Python se pueden transformar en una cadena de texto utilizando la función str()

# %%
h=str(g) #se usa str

# %% [markdown]
# **Sumar dos cadenas las concatena y produce una nueva:**

# %%
a= "soy alumne de la uam"
b= " y estudio antropología"

# %%
a+b #es la suma del comando que pedí con las dos variantes
# Out:
# 'soy alumne de la uam y estudio antropología'
